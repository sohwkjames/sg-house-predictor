# %%
import joblib
path = "../sg_housing_pipe.pkl"
# Open the pickle
rfr = joblib.load(path)

# %%
rfr.get_params()

data = joblib.load("../data.pkl")

# %%
data
# Out:
#          _id    month        town  flat_type block        street_name  \
# 0          1  2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10
# 1          2  2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4
# 2          3  2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5
# 3          4  2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10
# 4          5  2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5
# 5          6  2017-01  ANG MO KIO     3 ROOM   150   ANG MO KIO AVE 5
# 6          7  2017-01  ANG MO KIO     3 ROOM   447  ANG MO KIO AVE 10
# 7          8  2017-01  ANG MO KIO     3 ROOM   218   ANG MO KIO AVE 1
# 8          9  2017-01  ANG MO KIO     3 ROOM   447  ANG MO KIO AVE 10
# 9         10  2017-01  ANG MO KIO     3 ROOM   571   ANG MO KIO AVE 3
# 10        11  2017-01  ANG MO KIO     3 ROOM   534  ANG MO KIO AVE 10
# 11        12  2017-01  ANG MO KIO     3 ROOM   233   ANG MO KIO AVE 3
# ...
