# %%
import requests

class Pull_API_Data(self):
    def __init__(self, url=""):
        # if no value provided, use this value as the default url.
        self.url = 'https://data.gov.sg/api/action/datastore_search?resource_id=42ff9cfe-abe5-4b54-beda-c88f9bb438ee'
        self.data = {}
        
    def setUrl(url):
        self.url = url
        
    def getRecords():
        
    
        
    
    

import requests
url = 'https://data.gov.sg/api/action/datastore_search?resource_id=42ff9cfe-abe5-4b54-beda-c88f9bb438ee'
#response = requests.get(url)

# %%
response = requests.get(url)
response.json()
# Out:
# {'help': 'https://data.gov.sg/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'resource_id': '42ff9cfe-abe5-4b54-beda-c88f9bb438ee',
#   'fields': [{'type': 'int4', 'id': '_id'},
#    {'type': 'text', 'id': 'month'},
#    {'type': 'text', 'id': 'town'},
#    {'type': 'text', 'id': 'flat_type'},
#    {'type': 'text', 'id': 'block'},
#    {'type': 'text', 'id': 'street_name'},
#    {'type': 'text', 'id': 'storey_range'},
#    {'type': 'numeric', 'id': 'floor_area_sqm'},
#    {'type': 'text', 'id': 'flat_model'},
#    {'type': 'numeric', 'id': 'lease_commence_date'},
#    {'type': 'text', 'id': 'remaining_lease'},
#    {'type': 'numeric', 'id': 'resale_price'}],
#   'records': [{'town': 'ANG MO KIO',
#     'flat_type': '2 ROOM',
#     'flat_model': 'Improved',
#     'floor_area_sqm': '44',
#     'street_name': 'ANG MO KIO AVE 10',
#     'resale_price': '232000',
#     'month': '2017-01',
#     'remaining_lease': '61 years 04 months',
# ...

# %%
response.json()['result']['records']
# Out:
# [{'town': 'ANG MO KIO',
#   'flat_type': '2 ROOM',
#   'flat_model': 'Improved',
#   'floor_area_sqm': '44',
#   'street_name': 'ANG MO KIO AVE 10',
#   'resale_price': '232000',
#   'month': '2017-01',
#   'remaining_lease': '61 years 04 months',
#   'lease_commence_date': '1979',
#   'storey_range': '10 TO 12',
#   '_id': 1,
#   'block': '406'},
#  {'town': 'ANG MO KIO',
#   'flat_type': '3 ROOM',
#   'flat_model': 'New Generation',
#   'floor_area_sqm': '67',
#   'street_name': 'ANG MO KIO AVE 4',
#   'resale_price': '250000',
#   'month': '2017-01',
#   'remaining_lease': '60 years 07 months',
#   'lease_commence_date': '1978',
#   'storey_range': '01 TO 03',
#   '_id': 2,
#   'block': '108'},
#  {'town': 'ANG MO KIO',
#   'flat_type': '3 ROOM',
#   'flat_model': 'New Generation',
#   'floor_area_sqm': '67',
#   'street_name': 'ANG MO KIO AVE 5',
#   'resale_price': '262000',
#   'month': '2017-01',
#   'remaining_lease': '62 years 05 months',
#   'lease_commence_date': '1980',
# ...

# %%
pd.DataFrame(data)
# Out:
#     _id block      flat_model  flat_type floor_area_sqm lease_commence_date  \
# 0     1   406        Improved     2 ROOM             44                1979
# 1     2   108  New Generation     3 ROOM             67                1978
# 2     3   602  New Generation     3 ROOM             67                1980
# 3     4   465  New Generation     3 ROOM             68                1980
# 4     5   601  New Generation     3 ROOM             67                1980
# 5     6   150  New Generation     3 ROOM             68                1981
# 6     7   447  New Generation     3 ROOM             68                1979
# 7     8   218  New Generation     3 ROOM             67                1976
# 8     9   447  New Generation     3 ROOM             68                1979
# 9    10   571  New Generation     3 ROOM             67                1979
# 10   11   534  New Generation     3 ROOM             68                1980
# ...
